# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv('client_cpu_data.csv')
df2 = pd.read_csv('client_gpu_data.csv')
df3 = pd.read_csv('rd_cpu_data.csv')
df4 = pd.read_csv('rd_gpu_data.csv')

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
def three_d(df,x,y,z):
    ax = plt.axes(projection='3d')
    ax.plot3D(df[x], df[y], df[z], 'gray')
    ax.set_xlabel(x)
    ax.set_ylabel(y)
    ax.set_zlabel(z)

# %%
def three_d_scatter(df,x,y,z):
    ax = plt.axes(projection='3d')
    ax.scatter3D(df[x], df[y], df[z], c=df[z], cmap='Greens');
    ax.set_xlabel(x)
    ax.set_ylabel(y)
    ax.set_zlabel(z)

# %%
x = 'queued_time'
y = 'running_time'
z = 'cpu_num'
three_d(df1,x,y,z)

# %%
three_d_scatter(df1,x,y,z)

# %%
z1 = 'gpu_num'
three_d(df2,x,y,z1)

# %%
three_d_scatter(df2,x,y,z1)

# %%
three_d(df3,x,y,z)

# %%
three_d_scatter(df3,x,y,z)

# %%
three_d(df4,x,y,z1)

# %%
three_d_scatter(df4,x,y,z1)
